# %% [markdown]
# # Loop
# ## For Loop, While Loop

# %%
seq = [1,2,3,4,5]

for item in seq:
    print('Hello ' + str(item))
# Out:
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5

# %%
i = 1

while i < 100:
    print('i is: ' + str(i))
    i = i * 2
# Out:
# i is: 1
# i is: 2
# i is: 4
# i is: 8
# i is: 16
# i is: 32
# i is: 64
